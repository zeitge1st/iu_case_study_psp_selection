# %% [markdown]
# Fallstudie:<br>
# **Erstellen eines Prognosemodells des Kreditkartenzahlungsverkehr für Online-Einkäufe**

# %% [markdown]
# # Import & Helpers

# %%
#! mlflow server --host 127.0.0.1 --port 8080

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
pd.option_context('mode.use_inf_as_na', True)
pd.set_option('display.max_columns', 100)
import warnings
warnings.simplefilter("ignore", category=FutureWarning)

import datetime as dt
import numpy as np
import re

from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
sns.set(style='darkgrid',)
color_pal = sns.color_palette("muted")
sns.set_palette(color_pal)
sns.set_context("paper")
# %matplotlib inline
# plot dimensions
plot_width = 12
plot_height = 8
palette_success ={0: color_pal[1], 1: color_pal[2]}

from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import MinMaxScaler, OrdinalEncoder
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import CategoricalNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, ExtraTreesClassifier
from sklearn.metrics import roc_auc_score, precision_score, f1_score, recall_score, make_scorer
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

import mlflow
from mlflow.models import infer_signature

# %%
# parameter
rs = 23 # random state

# MLflow
mlflow.set_tracking_uri(uri="http://127.0.0.1:8080")

# date of today as string
dt_today = str(dt.date.today())

# %% [markdown]
# ## Track model in MFflow

# %%
def track_model(training_info, model, x_test, y_test, y_pred, y_pred_auc, feature_names):
    """
    Logging all relevant information (metrics, parameters and feature importances) of a trained model to MLflow.
    Model-specific feature importances is used (if existing) and Permutation Feature Importance.
    """
    # Set a tag as detailed description of run
    mlflow.set_tag("Training Info", training_info)
    
    # Log the hyperparameters
    mlflow.log_params(model.get_params())
    
    # Log the metrics
    mlflow.log_metrics({"AUC": roc_auc_score(y_test, y_pred_auc), 
                       "Precision": precision_score(y_test, y_pred, zero_division=np.nan), 
                       "Recall": recall_score(y_test, y_pred, zero_division=np.nan), 
                       "F1-score": f1_score(y_test, y_pred, zero_division=np.nan)})
     
    # check options to find out model-specific FEATURE IMPORTANCES
    plot_title = "No information on feature importances"
    if (hasattr(model, "feature_importances_") == True):
        feat_imp = model.feature_importances_
        plot_title = "Feature importances"
    elif (hasattr(model, "coef_") == True):
        feat_imp = model.coef_[0]
        plot_title = "Coefficients"
    else:
        feat_imp = len(feature_names) * [0]
        print("Has NO feature importances")
    
    # save feature importance to DF
    df_feat_imp = (pd.DataFrame(list(zip(feature_names, feat_imp)), 
                             columns=["Feature", "Model_specific_imp"])
                .set_index("Feature"))
    
    # PERMUTATION FEATURE IMPORTANCE (PFI) 
    pfi_result = permutation_importance(estimator=model, X=x_test, y=y_test, scoring="roc_auc", random_state=rs, n_repeats=10)
    df_pfi = (pd.DataFrame(list(zip(feature_names, pfi_result.importances_mean)), 
                           columns=["Feature", "PFI"])
              .set_index("Feature"))
    # join both dataframes
    df_feat_imp = df_feat_imp.join(df_pfi, how="left").sort_values("PFI", ascending=False).reset_index()
    
    csv_path = "artifacts/feature_importance.csv"
    df_feat_imp.to_csv(csv_path, index=True)
    mlflow.log_artifact(csv_path, "feature_importance.csv")
    
    # Log plot of feature importance
    fig, ax = plt.subplots(1, 2, figsize=(20,10))
    sns.barplot(y="Feature", x="Model_specific_imp", data=df_feat_imp, ax=ax[0])
    ax[0].set_title("Model-specific feature importances", fontsize=10)
    sns.barplot(y="Feature", x="PFI", data=df_feat_imp, ax=ax[1])
    ax[1].set_title("Permutation feature importances", fontsize=10)
    #plt.title(plot_title)
    #plt.xlabel("Importance")
    #plt.ylabel("Feature")
    plt.subplots_adjust(left=0.2, right=0.95, top=0.9, bottom=0.1, wspace=0.6)
    mlflow.log_figure(fig, "feature_importance.png")
    
    
    # Infer the model signature
    signature = infer_signature(x_train, y_train)
    
    # Log the model
    model_info = mlflow.sklearn.log_model(sk_model=model, 
                                          artifact_path="model_saved", 
                                          signature=signature, 
                                          input_example=x_train.head(5))

# %% [markdown]
# ## Training of model

# %%
def train_model(zip_iter, x_train_raw, x_train_numerical, x_test_raw, x_test_numerical, y_train, y_test, features_numerical, exp_name, info_text):
    """
    Iterates over a list of classifiers and parameters to train models. The trained models are tracked in MLflow.
    """
    for n, c, fm in zip_iter:
        print(f"Training and logging of model {n} as classifier {c} with feature mode {fm}")
        if fm == "raw":
            x_train = x_train_raw
            x_test = x_test_raw
            feature_names = list(x_train_raw.columns)
        else:
            x_train = x_train_numerical
            x_test = x_test_numerical
            feature_names = features_numerical
            
        # Create a new MLflow Experiment
        mlflow.set_experiment(exp_name)
        
        # Start an MLflow run
        run_name = n + "_" + exp_name
        with mlflow.start_run(run_name=run_name) as run:
            training_info = n + " - " + info_text
            # Training and prediction
            model = c
            model.fit(x_train, y_train)
            y_pred = model.predict(x_test)
    
            if (hasattr(model, "decision_function") == True):
                y_pred_auc = model.decision_function(x_test)
            else:
                y_pred_auc = model.predict_proba(x_test)[:, 1]
    
            track_model(training_info, model, x_test, y_test, y_pred, y_pred_auc, feature_names)
    
            run_id = run.info.run_id
        
        print(f"For {n}: Run logged in MLflow with {run_id}.")
        print("---------------------- \n")

# %% [markdown]
# ## Hypertune models

# %%
def hp_tune_model(search_mode, zip_iter, 
                  x_train_raw, x_train_numerical, 
                  x_test_raw, x_test_numerical, 
                  y_train, y_test, 
                  features_numerical, exp_name, info_text):
    """
    Iterates over a list of classifiers and parameters to train models. The trained models are tracked in MLflow.
    Choose between RandomSearchCV and GridSearchCV.
    search_mode = random/grid
    """
    
    # Config RandomizedSearchCV
    scorer_auc = make_scorer(roc_auc_score, response_method=["predict_proba", "decision_function"])
    scorer_precision = make_scorer(precision_score)
    scorer_recall = make_scorer(recall_score)
    scorer_f1 = make_scorer(f1_score)
    
    cv_scoring = {"auc": scorer_auc, 
                          "precision": scorer_precision, 
                          "recall": scorer_recall, 
                          "F1": scorer_f1}
    randomized_iter = 30
    cv_folds = 5
    rs = 23
    
    for n, c, p, fm in zip_iter:
        print(f"Training and logging of model {n} as classifier {c} with feature mode {fm}")
        if fm == "raw":
            x_train = x_train_raw
            x_test = x_test_raw
            feature_names = list(x_train_raw.columns)
        else:
            x_train = x_train_numerical
            x_test = x_test_numerical
            feature_names = features_numerical

        # Create a new MLflow Experiment
        mlflow.set_experiment(exp_name)
    
        # Start an MLflow run
        run_name = n + "_BEST_" + exp_name
        with mlflow.start_run(run_name=run_name) as run:
            training_info = n + " - " + info_text

            # RandomizedSearchCV or GridSearchCV
            if (search_mode == "random"):
                random_search = RandomizedSearchCV(c, 
                                                   param_distributions=p, 
                                                   n_iter=randomized_iter, 
                                                   verbose=2, 
                                                   cv=cv_folds, 
                                                   scoring=cv_scoring, 
                                                   refit="auc", 
                                                   random_state=rs, 
                                                   error_score="raise")
                # Training and prediction
                random_search.fit(x_train, y_train)
                model_best = random_search.best_estimator_
            else:
                grid_search = GridSearchCV(c, 
                                           param_grid=p, 
                                           scoring=cv_scoring, 
                                           refit="auc", 
                                           cv=cv_folds, 
                                           verbose=2, 
                                           error_score="raise")
                # Training and prediction
                grid_search.fit(x_train, y_train)
                model_best = grid_search.best_estimator_
                
            y_pred = model_best.predict(x_test)

            if (hasattr(model_best, "decision_function") == True):
                y_pred_auc = model_best.decision_function(x_test)
            else:
                y_pred_auc = model_best.predict_proba(x_test)[:, 1]
    
            track_model(training_info, model_best, x_test, y_test, y_pred, y_pred_auc, feature_names)
    
            run_id = run.info.run_id
        
        print(f"For {n}: Run logged in MLflow with {run_id}.")
        print("---------------------- \n")

# %% [markdown]
# # Data preparation 2

# %%
df_trx = (pd.read_excel("../data/03_interim/df_trx_training.xlsx", sheet_name="df_trx")
          .drop(columns=["Unnamed: 0"])
          .rename(columns={"x_tmsp":"meta_tmsp"}))

# %%
# raw x- and y-variables
x_ = [x for x in list(df_trx.columns) if re.match("^x_", x)!=None]
y_ = [y for y in list(df_trx.columns) if re.match("^y_", y)!=None]
meta_ = [m for m in list(df_trx.columns) if m.find("meta_")!=-1]

# %%
df_trx[x_].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37612 entries, 0 to 37611
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   x_country                  37612 non-null  object
#  1   x_amount                   37612 non-null  int64
#  2   x_psp                      37612 non-null  object
#  3   x_3d_secured               37612 non-null  int64
#  4   x_card                     37612 non-null  object
#  5   x_tmsp_wd_str              37612 non-null  object
#  6   x_tmsp_daytime             37612 non-null  object
#  7   x_tmsp_h_sin               37612 non-null  float64
#  8   x_tmsp_h_cos               37612 non-null  float64
#  9   x_tmsp_wd_sin              37612 non-null  float64
#  10  x_tmsp_wd_cos              37612 non-null  float64
#  11  x_enc_country_Austria      37612 non-null  bool
#  12  x_enc_country_Germany      37612 non-null  bool
#  13  x_enc_country_Switzerland  37612 non-null  bool
#  14  x_enc_psp_Goldcard         37612 non-null  bool
#  15  x_enc_psp_Moneycard        37612 non-null  bool
#  16  x_enc_psp_Simplecard       37612 non-null  bool
#  17  x_enc_psp_UK_Card          37612 non-null  bool
#  18  x_enc_card_Diners          37612 non-null  bool
#  19  x_enc_card_Master          37612 non-null  bool
#  20  x_enc_card_Visa            37612 non-null  bool
# dtypes: bool(10), float64(4), int64(2), object(5)
# memory usage: 3.5+ MB

# %% [markdown]
# Je nach Modell gibt es 2 Features-Sets:<br>
#
# Für Modelle, die numerische Features benötigen:
# - 16 Features
# - davon 6 numerische Features, die skaliert werden müssen
# - und 10 Features vom Typ Boolean, die aus dem One Hot Encoding entstanden sind und als Integer encoded werden<br>
#
# Für Modelle, bei denen der Typ der Features egal ist:
# - 7 Features
# - davon 2 numerische Features vom Typ Integer
# - und 5 categorial Features vom Typ Object

# %%
# categorize features
feat_object_native = list(df_trx[x_].select_dtypes(include="object").columns) # original features of type object
#feat_object_bool_enc = list(df_trx[x_].select_dtypes(include="bool").columns) # encoded object features as bool
feat_num = list(df_trx[x_].select_dtypes(include="int").columns) # numerical features for scaling

# %% [markdown]
# ## Train-Test-Split

# %%
# shuffle and stratify
x_train, x_test, y_train, y_test = train_test_split(df_trx[x_], df_trx[y_], test_size=0.2, random_state=rs, shuffle=True, stratify=df_trx[y_])
y_train= y_train.iloc[:, 0]
y_test= y_test.iloc[:, 0]

# %%
train_size = x_train.shape[0]
test_size = x_test.shape[0]
print(f"Trainings data set consists of {train_size} records, while the test data set consists of {test_size} records.")
# Out:
# Trainings data set consists of 30089 records, while the test data set consists of 7523 records.

# %% [markdown]
# ## Feature Engineering Pipeline

# %%
# column transformer for models requiring numerical, scaled input features
coltransformer_4numerical = make_column_transformer(
    (MinMaxScaler(), make_column_selector(dtype_include="number")), 
    (OrdinalEncoder(), make_column_selector(dtype_include="bool"))
)

# %% [markdown]
# ## Features

# %%
# for model with numerical input
coltransformer_4numerical.fit(x_train)
x_train_numerical = coltransformer_4numerical.transform(x_train)
x_test_numerical = coltransformer_4numerical.transform(x_test)

# %%
# names of transformed features
transformed_features = coltransformer_4numerical.get_feature_names_out()

# %%
# for model with raw input
x_train_raw = x_train[feat_num + feat_object_native]
x_test_raw = x_test[feat_num + feat_object_native]

# %% [markdown]
# # Modeling no. 1

# %% [markdown]
# ## Test design
# Ziele:
# - erfolgreiche Transaktionen in Abhängigkeit vom PSP (und den anderen Umständen) erkennen
# - positiv = success
# - wir müssen dem Kunden einen PSP zuordnen und wollen daher den PSP wählen, der die höchste Erfolgswahrscheinlichkeit hat
# - keine PSP zu wählen ist keine Option
#
# Vergleich der Modelle:
# - Wir sind nicht nur an der Klassifikation an sich interessiert, sondern v.a. auch an der Wahrscheinlichkeit für einen Erfolg abhängig von dem PSP. Der Predictor muss keine fixe Vorhersage über Erfolg/Misserfolg treffen, sondern in Abhängigkeit vom PSP die Erfolgswahrscheinlichkeit berechnen (es wird kein Threshold festgelegt).
# - AUC ist eine Vergleichsmetrik, die unabhängig vom gewählten Threshold ist.
#
# Weitere Metriken zur Bewertung der Performance, aber nicht entscheidend:
# - Precision meiner Vorhersage: keine Falschpositiven, um mehrfache Transaktionsgebühren zu sparen
# - Recall/TPR/Sensitivity: möglichst viele erfolgreiche Transaktionen vorhersagen, um eine Auswahl an PSPs zu haben, um die Kosten minimieren zu können
# - F1-Score als harmonisches Mittel

# %% [markdown]
# ## Baseline model
# 2 Strategien kommen in Frage:
# - most_frequent: macht wenig Sinn, weil dann kein Erfolg vorhergesagt wird, so dass Precision nicht berechnet werden kann. Recall/Sensitity ist ebenfalls = 0
# - stratified: It generates predictions by respecting the class distribution of the training data. It is different from the “most frequent” strategy as it instead associates a probability with each data point of being the most frequent class label.

# %%
# Training and prediction
baseline_clf = DummyClassifier(strategy="stratified", random_state=rs)
baseline_clf.fit(x_train_raw, y_train)

y_pred_baseline = baseline_clf.predict(x_test_raw)
y_pred_baseline_prob = baseline_clf.predict_proba(x_test_raw)
auc = roc_auc_score(y_test, y_pred_baseline_prob[:, 1], average="macro")
prec = precision_score(y_test, y_pred_baseline, zero_division=np.nan)
recall = recall_score(y_test, y_pred_baseline, zero_division=np.nan)
f1 = f1_score(y_test, y_pred_baseline, zero_division=np.nan)

print(f"Baseline-model")
print(f"with AUC: {auc:.2f}")
print(f"with precision: {prec:.2f}")
print(f"with recall: {recall:.2f}")
print(f"and F1-score: {f1:.2f}")
# Out:
# Baseline-model
# with AUC: 0.50
# with precision: 0.21
# with recall: 0.21
# and F1-score: 0.21

# %% [markdown]
# ## 1st training of models (w/o class_weights)
# https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.CategoricalNB.html#sklearn.naive_bayes.CategoricalNB<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html#sklearn.neighbors.KNeighborsClassifier<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn-tree-decisiontreeclassifier<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html#sklearn.svm.LinearSVC<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.discriminant_analysis.LinearDiscriminantAnalysis.html#sklearn.discriminant_analysis.LinearDiscriminantAnalysis<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis.html#sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn-ensemble-randomforestclassifier<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html#sklearn-ensemble-gradientboostingclassifier<br>
# https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesClassifier.html#sklearn.ensemble.ExtraTreesClassifier

# %%
class_weight = compute_class_weight(class_weight="balanced", classes=np.unique(y_train), y=y_train)

# %%
# collect all models
# names
first_step_clf_names = ["Baseline model stratified", 
                        "Logistic Regression", 
                        "Naive Bayes", 
                        "KNN", 
                        "Decision Tree", 
                        "Linear SVM",  
                        "SVC", 
                        "LDA", 
                        "QDA",
                        "Random Forest", 
                        "Gradient Boosting", 
                        "Extra Trees"]

# configure random see
params_rs = {"random_state": rs}

# sklearn models
first_step_clf = [DummyClassifier(strategy="stratified", **params_rs), 
                  LogisticRegression(class_weight="balanced", penalty=None, **params_rs), 
                  CategoricalNB(), 
                  KNeighborsClassifier(), 
                  DecisionTreeClassifier(class_weight="balanced", **params_rs),
                  LinearSVC(class_weight="balanced", **params_rs),
                  SVC(class_weight="balanced", probability=True, **params_rs), 
                  LinearDiscriminantAnalysis(), 
                  QuadraticDiscriminantAnalysis(),
                  RandomForestClassifier(class_weight="balanced_subsample", **params_rs), 
                  GradientBoostingClassifier(**params_rs), 
                  ExtraTreesClassifier(class_weight="balanced_subsample", **params_rs)]

# feature mode for model
first_step_feat_mode = ["raw", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric"]

first_step_zip = zip(first_step_clf_names, first_step_clf, first_step_feat_mode)
print(f"length of clf_names {len(first_step_clf_names)} & clf {len(first_step_clf)} & feat_mode {len(first_step_feat_mode)}")
# Out:
# length of clf_names 12 & clf 12 & feat_mode 12

# %%
first_exp = "PSP_1b_w/_class_weights"
first_info = "1. Training for comparison of models WITH hyperparameter tuning"
"""train_model(zip_iter=first_step_zip, 
            x_train_raw=x_train_raw, x_train_numerical=x_train_numerical, 
            x_test_raw=x_test_raw, x_test_numerical=x_test_numerical, 
            y_train=y_train, y_test=y_test,
            features_numerical=transformed_features, 
            exp_name=first_exp, info_text=first_info)"""
# Out:
# 'train_model(zip_iter=first_step_zip, \n            x_train_raw=x_train_raw, x_train_numerical=x_train_numerical, \n            x_test_raw=x_test_raw, x_test_numerical=x_test_numerical, \n            y_train=y_train, y_test=y_test,\n            features_numerical=transformed_features, \n            exp_name=first_exp, info_text=first_info)'

# %% [markdown]
# ## Evaluate & understand 1st model training
#
# Features with lowest performance:
# - Country: Austria, Germany, Switzerland
# - Working day

# %% [markdown]
# # Modeling no. 2: Remove least important features and models with lowest performance

# %% [markdown]
# ## Drop features

# %%
# LIGHT set for raw features
x_train_raw_light = x_train_raw.drop(columns=["x_tmsp_wd_str", "x_country"])
x_test_raw_light = x_test_raw.drop(columns=["x_tmsp_wd_str", "x_country"])

# %%
# columns to remove in numerical input
index_to_drop = [list(transformed_features).index(i) for i in transformed_features if (i.find("_country_")!=-1) or (i.find("_wd_")!=-1)]

# LIGHT set for model with numerical input
features_light = np.delete(transformed_features, index_to_drop, 0)
x_train_numerical_light = np.delete(x_train_numerical, index_to_drop, 1)
x_test_numerical_light = np.delete(x_test_numerical, index_to_drop, 1)

# %% [markdown]
# ## Training of models

# %%
# collect all models
# names
second_step_clf_names = ["Baseline model stratified", 
                        "Logistic Regression", 
                        "Naive Bayes", 
                        "KNN", 
                        "Decision Tree", 
                        "Linear SVM",  
                        "SVC", 
                        "LDA", 
                        "QDA",
                        "Random Forest", 
                        "Gradient Boosting", 
                        "Extra Trees"]

# sklearn models
second_step_clf = [DummyClassifier(strategy="stratified", **params_rs), 
                  LogisticRegression(class_weight="balanced", penalty=None, **params_rs), 
                  CategoricalNB(), 
                  KNeighborsClassifier(), 
                  DecisionTreeClassifier(class_weight="balanced", **params_rs),
                  LinearSVC(class_weight="balanced", **params_rs),
                  SVC(class_weight="balanced", probability=True, **params_rs), 
                  LinearDiscriminantAnalysis(), 
                  QuadraticDiscriminantAnalysis(),
                  RandomForestClassifier(class_weight="balanced_subsample", **params_rs), 
                  GradientBoostingClassifier(**params_rs), 
                  ExtraTreesClassifier(class_weight="balanced_subsample", **params_rs)]

# feature mode for model
second_step_feat_mode = ["raw", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric", 
                        "numeric"]

second_step_zip = zip(second_step_clf_names, second_step_clf, second_step_feat_mode)
print(f"length of clf_names {len(second_step_clf_names)} & clf {len(second_step_clf)} & feat_mode {len(second_step_feat_mode)}")
# Out:
# length of clf_names 12 & clf 12 & feat_mode 12

# %%
second_exp = "PSP_2b_w/_class_weights"
second_info = "2. Training of models w/ REDUCED features set &  WITHOUT hyperparameter tuning"
"""train_model(zip_iter=second_step_zip, 
            x_train_raw=x_train_raw_light, x_train_numerical=x_train_numerical_light, 
            x_test_raw=x_test_raw_light, x_test_numerical=x_test_numerical_light, 
            y_train=y_train, y_test=y_test,
            features_numerical=features_light, 
            exp_name=second_exp, info_text=second_info)"""
# Out:
# 'train_model(zip_iter=second_step_zip, \n            x_train_raw=x_train_raw_light, x_train_numerical=x_train_numerical_light, \n            x_test_raw=x_test_raw_light, x_test_numerical=x_test_numerical_light, \n            y_train=y_train, y_test=y_test,\n            features_numerical=features_light, \n            exp_name=second_exp, info_text=second_info)'

# %% [markdown]
# # Modeling no. 3: Random search for hyperparameter tuning
# Remove:
# - Dummy
# - Naive Bayes due to low optimization potential

# %%
# collect all models
# names
third_clf_names = ["Logistic Regression", 
                    "KNN", 
                    "Decision Tree", 
                    "Linear SVM",  
                    "SVC", 
                    "LDA", 
                    "QDA",
                    "Random Forest", 
                    "Gradient Boosting", 
                    "Extra Trees"]

# configure parameters per model
hp_baseline = {"strategy": ["most_frequent", "stratified"]}
hp_qda = {"reg_param": np.arange(0, 1.01, 0.1)}
hp_lda = {"shrinkage": [None, "auto"]}
hp_lr = {"penalty": ["l1", "l2", "elasticnet", None], 
         "C": np.arange(0.01, 10, 0.1), 
         "l1_ratio": np.arange(0.1, 1.01, 0.1)}
hp_knn = {"n_neighbors": np.arange(5, 75, 2), 
          "weights": ["uniform", "distance"], 
          "algorithm": ["ball_tree", "kd_tree", "brute"], 
          "p": np.arange(1, 3.0, 0.1)}
hp_dt = {"criterion": ["gini", "entropy", "log_loss"], 
         "splitter": ["best", "random"], 
         "max_depth": np.arange(2, 52, 2), 
         "min_samples_split": np.arange(2, 52, 2), 
         "min_samples_leaf": np.arange(1, 32, 2)}
hp_lin_svm = {"penalty": ["l1", "l2"], 
              "C": np.arange(0, 15, 0.5)}
hp_svc = {"C": np.arange(0, 10, 0.1), 
          "kernel": ["linear", "poly", "rbf", "sigmoid"], 
          "degree":[2, 3, 4, 5], 
          "gamma":["scale", "auto"]}
hp_rf = {"n_estimators": np.arange(10, 300, 20), 
         "criterion": ["gini", "entropy", "log_loss"], 
         "max_depth": np.arange(2, 60, 2), 
         "min_samples_split": np.arange(2, 50, 2), 
         "min_samples_leaf": np.arange(1, 30, 2), 
         "max_features": [None, "sqrt", "log2"]}
hp_grad_boost = {"loss": ["log_loss", "exponential"], 
                 "learning_rate":np.arange(0.1, 1.5, 0.1), 
                 "subsample": np.arange(0.3, 0.99, 0.1), 
                 "criterion": ["friedman_mse", "squared_error"], 
                 "min_samples_split": np.arange(2, 50, 2), 
                 "min_samples_leaf": np.arange(1, 30, 2), 
                 "max_depth": np.arange(2, 20, 1), 
                 "max_features": [None, "sqrt", "log2"]}
hp_extra = {"criterion": ["gini", "entropy", "log_loss"], 
            "max_depth": np.arange(2, 60, 2), 
            "min_samples_split": np.arange(2, 52, 2), 
            "min_samples_leaf": np.arange(1, 32, 2), 
            "max_features": [None, "sqrt", "log2"], 
            "min_weight_fraction_leaf": np.arange(0, 0.5, 0.1), 
            "bootstrap": [True, False]}

# parameters collected
third_params = [hp_lr, hp_knn, hp_dt, hp_lin_svm, hp_svc, hp_lda, hp_qda, hp_rf, hp_grad_boost, hp_extra]

# sklearn models
third_clf = [LogisticRegression(solver="saga", class_weight="balanced", **params_rs),  
              KNeighborsClassifier(), 
              DecisionTreeClassifier(class_weight="balanced", **params_rs),
              LinearSVC(dual="auto", class_weight="balanced", **params_rs),
              SVC(class_weight="balanced", probability=True, **params_rs), 
              LinearDiscriminantAnalysis(solver="lsqr"), 
              QuadraticDiscriminantAnalysis(),
              RandomForestClassifier(class_weight="balanced_subsample", **params_rs), 
              GradientBoostingClassifier(**params_rs), 
              ExtraTreesClassifier(class_weight="balanced_subsample", **params_rs)]

# feature mode for model
third_feat_mode = ["numeric", 
                    "numeric", 
                    "numeric", 
                    "numeric", 
                    "numeric", 
                    "numeric", 
                    "numeric", 
                    "numeric", 
                    "numeric", 
                    "numeric"]

third_zip = zip(third_clf_names, third_clf, third_params, third_feat_mode)
print(f"length of clf_names {len(third_clf_names)} & clf {len(third_clf)} & parameters {len(third_params)} & feat_mode {len(third_feat_mode)}")
# Out:
# length of clf_names 10 & clf 10 & parameters 10 & feat_mode 10

# %%
third_exp = "PSP_3b_HP-tune_w/_class_weights"
third_info = "3. Training of models WITH hyperparameter tuning & w/ REDUCED features set "
"""hp_tune_model(search_mode="random", 
              zip_iter=third_zip, 
              x_train_raw=x_train_raw_light, x_train_numerical=x_train_numerical_light, 
              x_test_raw=x_test_raw_light, x_test_numerical=x_test_numerical_light, 
              y_train=y_train, y_test=y_test, 
              features_numerical=features_light, 
              exp_name=third_exp, info_text=third_info)"""
# Out:
# 'hp_tune_model(search_mode="random", \n              zip_iter=third_zip, \n              x_train_raw=x_train_raw_light, x_train_numerical=x_train_numerical_light, \n              x_test_raw=x_test_raw_light, x_test_numerical=x_test_numerical_light, \n              y_train=y_train, y_test=y_test, \n              features_numerical=features_light, \n              exp_name=third_exp, info_text=third_info)'

# %% [markdown]
# # Modeling no. 4: Fine-tuning of Top3-models via GridSearch

# %%
# collect all models
# names
fourth_clf_names = ["Random Forest", "Decision Tree", "Extra Trees"]

# configure parameters per model
hp_fine_rf = {"max_depth": np.arange(15, 25, 1)}
hp_fine_dt = {"max_depth": np.arange(3, 13, 1)}
hp_fine_extra = {"max_depth": np.arange(45, 60, 1), "min_samples_split": np.arange(44, 58, 2)}

# parameters collected
fourth_params = [hp_fine_rf, hp_fine_dt, hp_fine_extra]

# sklearn models
fourth_clf = [RandomForestClassifier(class_weight="balanced_subsample", 
                                     bootstrap=True, n_estimators=190,
                                     min_samples_split=2, min_samples_leaf=29,
                                     criterion="entropy", max_features="log2", 
                                     random_state=rs), 
             DecisionTreeClassifier(class_weight="balanced", 
                                    criterion="log_loss", splitter="best", 
                                    min_samples_split=46, min_samples_leaf=5, 
                                    random_state=rs), 
             ExtraTreesClassifier(class_weight="balanced_subsample", criterion="entropy", 
                                  min_samples_leaf=13, max_features="sqrt", 
                                  min_weight_fraction_leaf=0, bootstrap=True, 
                                  random_state=rs)]

# feature mode for model
fourth_feat_mode = ["numeric", "numeric", "numeric"]

fourth_zip = zip(fourth_clf_names, fourth_clf, fourth_params, fourth_feat_mode)
print(f"length of clf_names {len(fourth_clf_names)} & clf {len(fourth_clf)} & parameters {len(fourth_params)} & feat_mode {len(fourth_feat_mode)}")
# Out:
# length of clf_names 3 & clf 3 & parameters 3 & feat_mode 3

# %%
fourth_exp = "PSP_4b_finetune_w/_class_weights"
fourth_info = "4. Training of models WITH hyperparameter tuning & w/ REDUCED features set "
hp_tune_model(search_mode="grid", 
              zip_iter=fourth_zip, 
              x_train_raw=x_train_raw_light, x_train_numerical=x_train_numerical_light, 
              x_test_raw=x_test_raw_light, x_test_numerical=x_test_numerical_light, 
              y_train=y_train, y_test=y_test, 
              features_numerical=features_light, 
              exp_name=fourth_exp, info_text=fourth_info)
# Out:
# Training and logging of model Random Forest as classifier RandomForestClassifier(class_weight='balanced_subsample', criterion='entropy',
#                        max_features='log2', min_samples_leaf=29,
#                        n_estimators=190, random_state=23) with feature mode numeric
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END .......................................max_depth=15; total time=   7.8s
# [CV] END .......................................max_depth=15; total time=   6.2s
# [CV] END .......................................max_depth=15; total time=   6.8s
# [CV] END .......................................max_depth=15; total time=   7.7s
# [CV] END .......................................max_depth=15; total time=   6.3s
# [CV] END .......................................max_depth=16; total time=   9.1s
# [CV] END .......................................max_depth=16; total time=   6.5s
# [CV] END .......................................max_depth=16; total time=   6.4s
# [CV] END .......................................max_depth=16; total time=   6.8s
# [CV] END .......................................max_depth=16; total time=   6.6s
# [CV] END .......................................max_depth=17; total time=   6.3s
# [CV] END .......................................max_depth=17; total time=   6.3s
# [CV] END .......................................max_depth=17; total time=   5.9s
# [CV] END .......................................max_depth=17; total time=   7.4s
# [CV] END .......................................max_depth=17; total time=   5.8s
# [CV] END .......................................max_depth=18; total time=   6.6s
# [CV] END .......................................max_depth=18; total time=   7.2s
# [CV] END .......................................max_depth=18; total time=   6.6s
# [CV] END .......................................max_depth=18; total time=   8.5s
# [CV] END .......................................max_depth=18; total time=   6.5s
# [CV] END .......................................max_depth=19; total time=   5.8s
# [CV] END .......................................max_depth=19; total time=   6.2s
# [CV] END .......................................max_depth=19; total time=   6.0s
# [CV] END .......................................max_depth=19; total time=   6.0s
# [CV] END .......................................max_depth=19; total time=   6.3s
# [CV] END .......................................max_depth=20; total time=   5.7s
# [CV] END .......................................max_depth=20; total time=   5.9s
# [CV] END .......................................max_depth=20; total time=   6.3s
# [CV] END .......................................max_depth=20; total time=   6.2s
# [CV] END .......................................max_depth=20; total time=   7.2s
# [CV] END .......................................max_depth=21; total time=   7.0s
# [CV] END .......................................max_depth=21; total time=   7.9s
# [CV] END .......................................max_depth=21; total time=   6.4s
# [CV] END .......................................max_depth=21; total time=   6.3s
# [CV] END .......................................max_depth=21; total time=   5.9s
# [CV] END .......................................max_depth=22; total time=   5.8s
# [CV] END .......................................max_depth=22; total time=   6.1s
# [CV] END .......................................max_depth=22; total time=   6.2s
# [CV] END .......................................max_depth=22; total time=   6.6s
# [CV] END .......................................max_depth=22; total time=   5.9s
# [CV] END .......................................max_depth=23; total time=   7.4s
# [CV] END .......................................max_depth=23; total time=   6.3s
# [CV] END .......................................max_depth=23; total time=   7.3s
# [CV] END .......................................max_depth=23; total time=   6.5s
# [CV] END .......................................max_depth=23; total time=   6.5s
# [CV] END .......................................max_depth=24; total time=   6.1s
# [CV] END .......................................max_depth=24; total time=   5.8s
# [CV] END .......................................max_depth=24; total time=   6.1s
# [CV] END .......................................max_depth=24; total time=   6.3s
# [CV] END .......................................max_depth=24; total time=   6.2s
# For Random Forest: Run logged in MLflow with 7803b273928848d6b42c3f190980050b.
# ----------------------
#
# Training and logging of model Decision Tree as classifier DecisionTreeClassifier(class_weight='balanced', criterion='log_loss',
#                        min_samples_leaf=5, min_samples_split=46,
#                        random_state=23) with feature mode numeric
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ........................................max_depth=3; total time=   0.1s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.1s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=9; total time=   0.0s
# [CV] END ........................................max_depth=9; total time=   0.0s
# [CV] END ........................................max_depth=9; total time=   0.0s
# [CV] END ........................................max_depth=9; total time=   0.1s
# [CV] END ........................................max_depth=9; total time=   0.1s
# [CV] END .......................................max_depth=10; total time=   0.1s
# [CV] END .......................................max_depth=10; total time=   0.0s
# [CV] END .......................................max_depth=10; total time=   0.0s
# [CV] END .......................................max_depth=10; total time=   0.0s
# [CV] END .......................................max_depth=10; total time=   0.0s
# [CV] END .......................................max_depth=11; total time=   0.1s
# [CV] END .......................................max_depth=11; total time=   0.1s
# [CV] END .......................................max_depth=11; total time=   0.0s
# [CV] END .......................................max_depth=11; total time=   0.0s
# [CV] END .......................................max_depth=11; total time=   0.0s
# [CV] END .......................................max_depth=12; total time=   0.0s
# [CV] END .......................................max_depth=12; total time=   0.0s
# [CV] END .......................................max_depth=12; total time=   0.1s
# [CV] END .......................................max_depth=12; total time=   0.0s
# [CV] END .......................................max_depth=12; total time=   0.1s
# For Decision Tree: Run logged in MLflow with 43706302127d464fa3f39efc6bbde01e.
# ----------------------
#
# Training and logging of model Extra Trees as classifier ExtraTreesClassifier(bootstrap=True, class_weight='balanced_subsample',
#                      criterion='entropy', min_samples_leaf=13,
#                      min_weight_fraction_leaf=0, random_state=23) with feature mode numeric
# Fitting 5 folds for each of 105 candidates, totalling 525 fits
# [CV] END .................max_depth=45, min_samples_split=44; total time=   3.0s
# [CV] END .................max_depth=45, min_samples_split=44; total time=   2.4s
# [CV] END .................max_depth=45, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=45, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=45, min_samples_split=44; total time=   2.2s
# [CV] END .................max_depth=45, min_samples_split=46; total time=   2.3s
# [CV] END .................max_depth=45, min_samples_split=46; total time=   2.2s
# [CV] END .................max_depth=45, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=45, min_samples_split=46; total time=   2.5s
# [CV] END .................max_depth=45, min_samples_split=46; total time=   2.5s
# [CV] END .................max_depth=45, min_samples_split=48; total time=   2.2s
# [CV] END .................max_depth=45, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=45, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=45, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=45, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=45, min_samples_split=50; total time=   2.4s
# [CV] END .................max_depth=45, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=45, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=45, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=45, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=45, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=45, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=45, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=45, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=45, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=45, min_samples_split=54; total time=   2.2s
# [CV] END .................max_depth=45, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=45, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=45, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=45, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=45, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=45, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=45, min_samples_split=56; total time=   1.7s
# [CV] END .................max_depth=45, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=45, min_samples_split=56; total time=   2.1s
# [CV] END .................max_depth=46, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=46, min_samples_split=44; total time=   2.1s
# [CV] END .................max_depth=46, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=46, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=46, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=46, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=46, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=46, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=46, min_samples_split=46; total time=   2.2s
# [CV] END .................max_depth=46, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=46, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=46, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=46, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=46, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=46, min_samples_split=48; total time=   2.2s
# [CV] END .................max_depth=46, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=46, min_samples_split=50; total time=   1.6s
# [CV] END .................max_depth=46, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=46, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=46, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=46, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=46, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=46, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=46, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=46, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=46, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=46, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=46, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=46, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=46, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=46, min_samples_split=56; total time=   2.2s
# [CV] END .................max_depth=46, min_samples_split=56; total time=   2.2s
# [CV] END .................max_depth=46, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=46, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=46, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=47, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=47, min_samples_split=44; total time=   2.4s
# [CV] END .................max_depth=47, min_samples_split=44; total time=   2.2s
# [CV] END .................max_depth=47, min_samples_split=44; total time=   2.1s
# [CV] END .................max_depth=47, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=47, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=47, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=47, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=47, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=47, min_samples_split=46; total time=   2.5s
# [CV] END .................max_depth=47, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=47, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=47, min_samples_split=48; total time=   2.2s
# [CV] END .................max_depth=47, min_samples_split=48; total time=   2.2s
# [CV] END .................max_depth=47, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=47, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=47, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=47, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=47, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=47, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=47, min_samples_split=52; total time=   1.7s
# [CV] END .................max_depth=47, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=47, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=47, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=47, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=47, min_samples_split=54; total time=   2.1s
# [CV] END .................max_depth=47, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=47, min_samples_split=54; total time=   2.2s
# [CV] END .................max_depth=47, min_samples_split=54; total time=   2.5s
# [CV] END .................max_depth=47, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=47, min_samples_split=56; total time=   2.2s
# [CV] END .................max_depth=47, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=47, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=47, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=47, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=48, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=48, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=44; total time=   2.2s
# [CV] END .................max_depth=48, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=48, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=48, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=48, min_samples_split=46; total time=   2.1s
# [CV] END .................max_depth=48, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=48, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=48, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=48; total time=   1.9s
# [CV] END .................max_depth=48, min_samples_split=48; total time=   1.9s
# [CV] END .................max_depth=48, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=48, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=48, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=48, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=48, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=48, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=48, min_samples_split=52; total time=   2.3s
# [CV] END .................max_depth=48, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=48, min_samples_split=54; total time=   2.3s
# [CV] END .................max_depth=48, min_samples_split=54; total time=   2.4s
# [CV] END .................max_depth=48, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=56; total time=   2.3s
# [CV] END .................max_depth=48, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=48, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=48, min_samples_split=56; total time=   2.1s
# [CV] END .................max_depth=49, min_samples_split=44; total time=   2.1s
# [CV] END .................max_depth=49, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=49, min_samples_split=44; total time=   2.1s
# [CV] END .................max_depth=49, min_samples_split=44; total time=   2.1s
# [CV] END .................max_depth=49, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=49, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=49, min_samples_split=46; total time=   2.2s
# [CV] END .................max_depth=49, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=49, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=49, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=49, min_samples_split=48; total time=   1.9s
# [CV] END .................max_depth=49, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=49, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=49, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=49, min_samples_split=48; total time=   2.2s
# [CV] END .................max_depth=49, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=49, min_samples_split=50; total time=   2.3s
# [CV] END .................max_depth=49, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=49, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=49, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=49, min_samples_split=52; total time=   1.6s
# [CV] END .................max_depth=49, min_samples_split=52; total time=   2.2s
# [CV] END .................max_depth=49, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=49, min_samples_split=52; total time=   2.3s
# [CV] END .................max_depth=49, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=49, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=49, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=49, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=49, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=49, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=49, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=49, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=49, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=49, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=49, min_samples_split=56; total time=   1.7s
# [CV] END .................max_depth=50, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=50, min_samples_split=44; total time=   2.1s
# [CV] END .................max_depth=50, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=50, min_samples_split=46; total time=   2.2s
# [CV] END .................max_depth=50, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=50, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=50, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=50, min_samples_split=48; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=50, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=50, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=50, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=50, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=50, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=50, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=50, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=50, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=50, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=50, min_samples_split=54; total time=   1.6s
# [CV] END .................max_depth=50, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=50, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=50, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=50, min_samples_split=56; total time=   2.1s
# [CV] END .................max_depth=50, min_samples_split=56; total time=   2.2s
# [CV] END .................max_depth=50, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=50, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=51, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=51, min_samples_split=44; total time=   2.2s
# [CV] END .................max_depth=51, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=51, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=51, min_samples_split=44; total time=   2.2s
# [CV] END .................max_depth=51, min_samples_split=46; total time=   2.2s
# [CV] END .................max_depth=51, min_samples_split=46; total time=   2.4s
# [CV] END .................max_depth=51, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=51, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=51, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=51, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=51, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=51, min_samples_split=48; total time=   1.9s
# [CV] END .................max_depth=51, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=51, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=51, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=51, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=51, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=51, min_samples_split=50; total time=   2.2s
# [CV] END .................max_depth=51, min_samples_split=50; total time=   2.4s
# [CV] END .................max_depth=51, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=51, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=51, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=51, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=51, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=51, min_samples_split=54; total time=   2.3s
# [CV] END .................max_depth=51, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=51, min_samples_split=54; total time=   1.6s
# [CV] END .................max_depth=51, min_samples_split=54; total time=   1.6s
# [CV] END .................max_depth=51, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=51, min_samples_split=56; total time=   1.5s
# [CV] END .................max_depth=51, min_samples_split=56; total time=   1.6s
# [CV] END .................max_depth=51, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=51, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=51, min_samples_split=56; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=46; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=46; total time=   1.6s
# [CV] END .................max_depth=52, min_samples_split=46; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=48; total time=   1.6s
# [CV] END .................max_depth=52, min_samples_split=48; total time=   1.6s
# [CV] END .................max_depth=52, min_samples_split=48; total time=   1.6s
# [CV] END .................max_depth=52, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=52, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=52; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=52; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=52; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=52, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=54; total time=   1.6s
# [CV] END .................max_depth=52, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=56; total time=   1.7s
# [CV] END .................max_depth=52, min_samples_split=56; total time=   1.6s
# [CV] END .................max_depth=52, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=52, min_samples_split=56; total time=   1.6s
# [CV] END .................max_depth=53, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=53, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=44; total time=   1.6s
# [CV] END .................max_depth=53, min_samples_split=46; total time=   2.4s
# [CV] END .................max_depth=53, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=53, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=53, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=53, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=53, min_samples_split=48; total time=   1.6s
# [CV] END .................max_depth=53, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=48; total time=   1.6s
# [CV] END .................max_depth=53, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=53, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=53, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=53, min_samples_split=50; total time=   1.6s
# [CV] END .................max_depth=53, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=52; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=53, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=53, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=53, min_samples_split=52; total time=   2.2s
# [CV] END .................max_depth=53, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=53, min_samples_split=54; total time=   1.6s
# [CV] END .................max_depth=53, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=53, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=53, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=53, min_samples_split=56; total time=   1.7s
# [CV] END .................max_depth=53, min_samples_split=56; total time=   1.5s
# [CV] END .................max_depth=54, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=54, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=54, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=54, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=54, min_samples_split=46; total time=   1.6s
# [CV] END .................max_depth=54, min_samples_split=46; total time=   1.6s
# [CV] END .................max_depth=54, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=54, min_samples_split=48; total time=   1.6s
# [CV] END .................max_depth=54, min_samples_split=48; total time=   1.6s
# [CV] END .................max_depth=54, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=54, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=54, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=54, min_samples_split=52; total time=   1.6s
# [CV] END .................max_depth=54, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=54, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=54, min_samples_split=52; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=54; total time=   1.6s
# [CV] END .................max_depth=54, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=54, min_samples_split=54; total time=   1.6s
# [CV] END .................max_depth=54, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=54, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=54, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=54, min_samples_split=56; total time=   1.7s
# [CV] END .................max_depth=54, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=55, min_samples_split=44; total time=   1.6s
# [CV] END .................max_depth=55, min_samples_split=44; total time=   1.6s
# [CV] END .................max_depth=55, min_samples_split=44; total time=   1.6s
# [CV] END .................max_depth=55, min_samples_split=44; total time=   1.6s
# [CV] END .................max_depth=55, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=55, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=55, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=55, min_samples_split=46; total time=   1.7s
# [CV] END .................max_depth=55, min_samples_split=46; total time=   1.7s
# [CV] END .................max_depth=55, min_samples_split=46; total time=   1.6s
# [CV] END .................max_depth=55, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=55, min_samples_split=48; total time=   1.6s
# [CV] END .................max_depth=55, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=55, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=55, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=55, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=55, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=55, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=55, min_samples_split=50; total time=   2.2s
# [CV] END .................max_depth=55, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=55, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=55, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=55, min_samples_split=52; total time=   2.2s
# [CV] END .................max_depth=55, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=55, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=55, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=55, min_samples_split=54; total time=   2.1s
# [CV] END .................max_depth=55, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=55, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=55, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=55, min_samples_split=56; total time=   1.7s
# [CV] END .................max_depth=55, min_samples_split=56; total time=   2.2s
# [CV] END .................max_depth=55, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=55, min_samples_split=56; total time=   1.7s
# [CV] END .................max_depth=55, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=56, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=56, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=56, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=56, min_samples_split=44; total time=   2.4s
# [CV] END .................max_depth=56, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=56, min_samples_split=46; total time=   2.1s
# [CV] END .................max_depth=56, min_samples_split=46; total time=   2.1s
# [CV] END .................max_depth=56, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=56, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=56, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=56, min_samples_split=48; total time=   2.3s
# [CV] END .................max_depth=56, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=56, min_samples_split=48; total time=   1.9s
# [CV] END .................max_depth=56, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=56, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=56, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=56, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=56, min_samples_split=50; total time=   2.2s
# [CV] END .................max_depth=56, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=56, min_samples_split=50; total time=   2.3s
# [CV] END .................max_depth=56, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=56, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=56, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=56, min_samples_split=52; total time=   2.1s
# [CV] END .................max_depth=56, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=56, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=56, min_samples_split=54; total time=   1.7s
# [CV] END .................max_depth=56, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=56, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=56, min_samples_split=54; total time=   2.1s
# [CV] END .................max_depth=56, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=56, min_samples_split=56; total time=   2.4s
# [CV] END .................max_depth=56, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=56, min_samples_split=56; total time=   2.1s
# [CV] END .................max_depth=56, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=57, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=57, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=44; total time=   2.3s
# [CV] END .................max_depth=57, min_samples_split=46; total time=   2.1s
# [CV] END .................max_depth=57, min_samples_split=46; total time=   2.1s
# [CV] END .................max_depth=57, min_samples_split=46; total time=   2.2s
# [CV] END .................max_depth=57, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=46; total time=   2.3s
# [CV] END .................max_depth=57, min_samples_split=48; total time=   2.4s
# [CV] END .................max_depth=57, min_samples_split=48; total time=   2.2s
# [CV] END .................max_depth=57, min_samples_split=48; total time=   2.2s
# [CV] END .................max_depth=57, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=57, min_samples_split=48; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=50; total time=   1.6s
# [CV] END .................max_depth=57, min_samples_split=50; total time=   2.2s
# [CV] END .................max_depth=57, min_samples_split=50; total time=   2.2s
# [CV] END .................max_depth=57, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=57, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=57, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=57, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=52; total time=   2.5s
# [CV] END .................max_depth=57, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=57, min_samples_split=54; total time=   2.2s
# [CV] END .................max_depth=57, min_samples_split=54; total time=   2.1s
# [CV] END .................max_depth=57, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=54; total time=   2.2s
# [CV] END .................max_depth=57, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=57, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=57, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=57, min_samples_split=56; total time=   1.7s
# [CV] END .................max_depth=57, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=58, min_samples_split=44; total time=   2.2s
# [CV] END .................max_depth=58, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=58, min_samples_split=44; total time=   1.8s
# [CV] END .................max_depth=58, min_samples_split=44; total time=   2.2s
# [CV] END .................max_depth=58, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=58, min_samples_split=46; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=58, min_samples_split=46; total time=   2.1s
# [CV] END .................max_depth=58, min_samples_split=46; total time=   2.2s
# [CV] END .................max_depth=58, min_samples_split=48; total time=   2.0s
# [CV] END .................max_depth=58, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=58, min_samples_split=48; total time=   1.7s
# [CV] END .................max_depth=58, min_samples_split=48; total time=   2.2s
# [CV] END .................max_depth=58, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=58, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=58, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=58, min_samples_split=52; total time=   1.7s
# [CV] END .................max_depth=58, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=58, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=58, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=58, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=58, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=58, min_samples_split=54; total time=   1.5s
# [CV] END .................max_depth=58, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=56; total time=   2.0s
# [CV] END .................max_depth=58, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=58, min_samples_split=56; total time=   2.1s
# [CV] END .................max_depth=58, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=59, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=44; total time=   1.7s
# [CV] END .................max_depth=59, min_samples_split=44; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=44; total time=   2.0s
# [CV] END .................max_depth=59, min_samples_split=44; total time=   2.1s
# [CV] END .................max_depth=59, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=59, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=59, min_samples_split=46; total time=   2.1s
# [CV] END .................max_depth=59, min_samples_split=46; total time=   1.8s
# [CV] END .................max_depth=59, min_samples_split=46; total time=   2.0s
# [CV] END .................max_depth=59, min_samples_split=48; total time=   2.3s
# [CV] END .................max_depth=59, min_samples_split=48; total time=   2.1s
# [CV] END .................max_depth=59, min_samples_split=48; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=48; total time=   1.8s
# [CV] END .................max_depth=59, min_samples_split=48; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=50; total time=   1.8s
# [CV] END .................max_depth=59, min_samples_split=50; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=50; total time=   2.0s
# [CV] END .................max_depth=59, min_samples_split=50; total time=   1.7s
# [CV] END .................max_depth=59, min_samples_split=50; total time=   2.1s
# [CV] END .................max_depth=59, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=52; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=59, min_samples_split=52; total time=   1.8s
# [CV] END .................max_depth=59, min_samples_split=52; total time=   2.0s
# [CV] END .................max_depth=59, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=54; total time=   2.0s
# [CV] END .................max_depth=59, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=54; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=54; total time=   1.8s
# [CV] END .................max_depth=59, min_samples_split=56; total time=   1.9s
# [CV] END .................max_depth=59, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=59, min_samples_split=56; total time=   1.8s
# [CV] END .................max_depth=59, min_samples_split=56; total time=   2.1s
# [CV] END .................max_depth=59, min_samples_split=56; total time=   1.8s
# For Extra Trees: Run logged in MLflow with 3fa0b4b7449b4029b19adb4eb6f05937.
# ----------------------

# %% [markdown]
# # Modeling no. 5: Train best-fit and save model
# Random Forest with best performance

# %%
logged_model = 'runs:/7803b273928848d6b42c3f190980050b/model_saved'

# Load model as a PyFuncModel.
best_model = mlflow.pyfunc.load_model(logged_model)

# %%
x_test_numerical
# Out:
# array([[0.62019231, 0.        , 0.9330127 , ..., 0.        , 1.        ,
#         0.        ],
#        [0.29647436, 1.        , 0.37059048, ..., 1.        , 0.        ,
#         0.        ],
#        [0.3349359 , 0.        , 0.37059048, ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.58653846, 1.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.45192308, 0.        , 0.0669873 , ..., 1.        , 0.        ,
#         0.        ],
#        [0.44391026, 0.        , 0.25      , ..., 0.        , 1.        ,
#         0.        ]])

# %% [markdown]
# # Evaluation
# - Filtern nach den 1. Versuchen
# - Prognose für die PSP
# - Vergleich mit tatsächlich gewähltem PSP
