# %% [markdown]
# Fallstudie:<br>
# **Erstellen eines Prognosemodells des Kreditkartenzahlungsverkehr für Online-Einkäufe**

# %%
import pandas as pd
pd.option_context('mode.use_inf_as_na', True)
pd.set_option('display.max_columns', 100)
import warnings
warnings.simplefilter("ignore", category=FutureWarning)

import datetime as dt
import numpy as np
import re

import sys
sys.path.insert(0, "C:/Users/czump/Documents/GitHub/iu_case_study_psp_selection/src")
from helpers import cyclical_encoding, binning_h

from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
sns.set(style='darkgrid',)
color_pal = sns.color_palette("muted")
sns.set_palette(color_pal)
sns.set_context("paper")
# %matplotlib inline
# plot dimensions
plot_width = 12
plot_height = 8
palette_success ={0: color_pal[1], 1: color_pal[2]}

# %% [markdown]
# # Business understanding
# **Aktuelle Situation:**<br>
# - Einzelhandelsunternehmen hat Verträge mit 4 versch. payment service provider (PSP) für Online-Kreditkartenzahlungen
# - Auswahl eines PSPs für eine Überweisung erfolgt auf Basis eines fixen Regelwerks
# - Ausfallrate an Online-Kreditkartenzahlungen ist hoch
# - Konsequenz: hohe Kosten für das Unternehmen und unzufriedene Kunden
#
# **Geschäftsziele:**<br>
# - Ablösen des fixen, manuellen Regelwerks durch ein Prognosemodell zur Auswahl eines PSPs für eine Zahlung
# - Verbesserung der Erfolgsrate der Transaktionen
# - Reduzierung der Transaktionskosten
#
# **Erfolgskriterien:**<br>
# - höhere Erfolgsrate der Transaktionen (first time through)
# - und niedrigere Transaktionskosten gegenüber der aktuellen Situation

# %% [markdown]
# # Data understanding

# %% [markdown]
# ## Collect initial data
# **Hauptdatensatz:**<br>
# Initialer Datensatz vom Januar und Februar 2019 mit den Kreditkartentransaktionen der DACH Länder<br>
#
# **Kostendaten:**<br>
# Transaktionskosten für erfolgreiche und fehlgeschlagene Transaktionen je PSP

# %%
# transactions
df_t_in = pd.read_excel("../data/01_raw/PSP_Jan_Feb_2019.xlsx").set_index(keys="Unnamed: 0", drop=True)

# %%
df_t_in.head()
# Out:
#                           tmsp  country  amount  success         PSP  \
# Unnamed: 0
# 0          2019-01-01 00:01:11  Germany      89        0     UK_Card
# 1          2019-01-01 00:01:17  Germany      89        1     UK_Card
# 2          2019-01-01 00:02:49  Germany     238        0     UK_Card
# 3          2019-01-01 00:03:13  Germany     238        1     UK_Card
# 4          2019-01-01 00:04:33  Austria     124        0  Simplecard
#
#             3D_secured    card
# Unnamed: 0
# 0                    0    Visa
# 1                    0    Visa
# 2                    1  Diners
# 3                    1  Diners
# 4                    0  Diners

# %%
# cost data
cost_dict = {"PSP_name": ["Moneycard", "Goldcard", "UK_Card", "Simplecard"], 
             "fee_success_EUR": [5, 10, 3, 1], 
             "fee_failed_EUR": [2, 5, 1, 0.5]}
df_cost_in = pd.DataFrame(cost_dict, columns=["PSP_name", "fee_success_EUR", "fee_failed_EUR"])

# %%
df_cost_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PSP_name         4 non-null      object
#  1   fee_success_EUR  4 non-null      int64
#  2   fee_failed_EUR   4 non-null      float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 228.0+ bytes

# %% [markdown]
# ## Describe data
# 6 unabhängige Variablen und 1 Zielvariable (success) mit knapp 50.000 Datensätzen<br>
# Datenformat korrekt erkannt<br>
# keine fehlenden Werte<br>

# %%
df_t_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50410 entries, 0 to 50409
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tmsp        50410 non-null  datetime64[ns]
#  1   country     50410 non-null  object
#  2   amount      50410 non-null  int64
#  3   success     50410 non-null  int64
#  4   PSP         50410 non-null  object
#  5   3D_secured  50410 non-null  int64
#  6   card        50410 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 3.1+ MB

# %%
df_t_in.describe()
# Out:
#                                 tmsp        amount       success    3D_secured
# count                          50410  50410.000000  50410.000000  50410.000000
# mean   2019-01-29 16:28:52.923269120    202.395715      0.202896      0.238266
# min              2019-01-01 00:01:11      6.000000      0.000000      0.000000
# 25%    2019-01-14 12:00:36.249999872    133.000000      0.000000      0.000000
# 50%       2019-01-30 15:20:07.500000    201.000000      0.000000      0.000000
# 75%       2019-02-13 01:09:50.500000    269.000000      0.000000      0.000000
# max              2019-02-28 23:48:19    630.000000      1.000000      1.000000
# std                              NaN     96.274730      0.402160      0.426027

# %%
# dictionary to rename columns
rename_cols = {"tmsp":"x_tmsp", 
               "country":"x_country", 
               "amount":"x_amount", 
               "PSP":"x_psp", 
               "3D_secured":"x_3d_secured", 
               "card":"x_card", 
               "success":"y_success"}

df_t_in.rename(columns=rename_cols, inplace=True)

# raw x- and y-variables
x_raw = [x for x in list(df_t_in.columns) if x.find("x_")!=-1]
y_raw = [y for y in list(df_t_in.columns) if re.match("^y_", y)!=None]

# %% [markdown]
# ## Explore data

# %% [markdown]
# ### Verteilung über Histogramme

# %%
fig, axs = plt.subplots(4,2, figsize=(12, 12), sharex=False, tight_layout=True)

# Timestamp
sns.histplot(df_t_in, x="x_tmsp", stat="count", ax=axs[0, 0])
axs[0, 0].set_title("Feature: timestamp")
for label in axs[0, 0].get_xticklabels():
    label.set_rotation(45)

# Country
sns.histplot(df_t_in, x="x_country", discrete=True, shrink=.8, stat="count", ax=axs[0, 1])
axs[0, 1].set_title("Feature: country")

# Amount
sns.histplot(df_t_in, x="x_amount", stat="count", ax=axs[1, 0])
axs[1, 0].set_title("Feature: amount")

# PSP
sns.histplot(df_t_in, x="x_psp", discrete=True, shrink=.8, stat="count", ax=axs[1, 1])
axs[1, 1].set_title("Feature: PSP")

# 3d_secured
sns.histplot(df_t_in, x="x_3d_secured", discrete=True, shrink=.8, stat="count", ax=axs[2, 0])
axs[2, 0].set_xticks(range(0,2))
axs[2, 0].set_title("Feature: 3D secured")

# card
sns.histplot(df_t_in, x="x_card", discrete=True, shrink=.8, stat="count", ax=axs[2, 1])
axs[2, 1].set_title("Feature: card")

# card
sns.histplot(df_t_in, x="y_success", discrete=True, shrink=.8, stat="count", ax=axs[3, 0])
axs[3, 0].set_xticks(range(0,2))
axs[3, 0].set_title("Target: success")
axs[3, 0].patches[0].set_facecolor(color_pal[1])
axs[3, 0].patches[1].set_facecolor(color_pal[2])

plt.subplots_adjust(hspace=0.3, top = 0.93, bottom = 0.02) 
fig.suptitle("Histograms of variables") 
plt.savefig("../reports/figures/2-3-1_histogram.png")
plt.show() 
plt.close()

# %% [markdown]
# > Amount muss genauer angeschaut werden, da es hier einige Ausreißer nach oben gibt

# %%
plt.figure(figsize=(plot_width, plot_height))
sns.displot(df_t_in, x="x_amount", bins=20)
plt.title("Histogram of variable amount")
plt.show()
plt.close()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x="x_amount", orient="h", data=df_t_in)
plt.title("Boxplot of variable amount")
plt.savefig("../reports/figures/2-3-1_boxplot_amount.png")
plt.show()
plt.close()

# %% [markdown]
# Findings:
# > Outliers bei Amount: > 500 EUR stehe nur noch sehr wenige Datensätze zur Verfügung. <br>
# > PSPs: Goldcard ist stark unterrepräsentiert. Das sollte bei der Prognose berücksichtigt werden.<br>
# > Success: Es gibt mehr fehlgeschlagene Versuche, als erfolgreiche Versuche. Daher muss es sehr viele Mehrfachversuche geben, die identifiziert werden müssen.

# %% [markdown]
# ### Korrelation überprüfen
# Es liegt mit "amount" nur sehr wenige numerische Variablen vor, wobei nur die Variable "amount" kontinuierliche Daher kann die Korrelation auch nur begrenzt bewertet werden.<br>
# Bei den Korrelation ist wie erwartet sehr schwach, da auch nur sehr wenige numerische Wert

# %%
corr_pearson_raw = df_t_in.corr(method="pearson", numeric_only=True)
corr_pearson_raw
# Out:
#               x_amount  y_success  x_3d_secured
# x_amount      1.000000  -0.086423      0.000178
# y_success    -0.086423   1.000000      0.059284
# x_3d_secured  0.000178   0.059284      1.000000

# %%
sns.heatmap(corr_pearson_raw, annot=True, vmin=-1, vmax=1, center=0.0, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >

# %%
corr_grid = sns.PairGrid(df_t_in, hue=y_raw[0], palette=palette_success, vars=x_raw)
corr_grid.map(plt.scatter)
plt.show()

# %% [markdown]
# ## Verify data quality
# Datenqualität ist gut:
# - keine fehlenden Werte
# - alle Werte stimmen mit dem erwarteten Datenformat überein

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Select and clean data
# Evtl. Bereinigung der Outliers?

# %% [markdown]
# ## Construct data
# - Mehrfachversuche identifizieren
# - Werte kodieren

# %% [markdown]
# ### Mehrfachversuche identifizieren
# Überweisungen werden als mehrfache Zahlungsversuche gezählt, wenn:
# - im selben Land
# - mit demselben Überweisungsbetrag
# - innerhalb derselben Minute
# - und es noch keine erfolgreiche Transaktion für dieses Setting gab
#
# Zuerst **Auswertung aus der Perspektive des Kunden:**<br>
# Bündeln der Transaktionen, die zu einem Kundenvorgang gehören und ggfs. aus mehreren Versuchen des Kunden bestehen.

# %%
# sort to get correct order and reset index
df_t_processed = (df_t_in
                  .sort_values(by=["x_country", "x_amount", "x_tmsp"], ascending=True, inplace=False)
                  .reset_index()
                  .drop(columns=["Unnamed: 0"]))

# calculate timedifference between to consecutive rows and convert to minutes
df_t_processed["time_diff_min"] = df_t_processed["x_tmsp"].diff(periods=1).dt.total_seconds().div(60)

# init lists
cust_transaction_id = [] # from customer perspective: ID for each transaction ; can consist of several attempts
cust_attempt_no = [] # from customer perspective: no. of attempts for each transaction

# iter over dataframe
for idx, row in df_t_processed.iterrows():
    if (idx == 0):
        # first rows -> new transaction
        cust_transaction_id.append(0)
        cust_attempt_no.append(1)
    else: # not first row
        country_curr = df_t_processed.at[idx, "x_country"]
        country_prev = df_t_processed.at[idx-1, "x_country"]
        amount_curr = df_t_processed.at[idx, "x_amount"]
        amount_prev = df_t_processed.at[idx-1, "x_amount"]
        timediff = df_t_processed.at[idx, "time_diff_min"]
        success_prev = df_t_processed.at[idx-1, "y_success"]
    
        if (success_prev == 1) or (country_curr != country_prev) or (amount_curr != amount_prev) or (timediff > 60):
            # success in prev attempt
            # or different attempt -> new transaction and first attempt
            cust_transaction_id.append(cust_transaction_id[-1]+1)
            cust_attempt_no.append(1)
        else:
            # similar attempt happened already -> same transaction + new attempt
            cust_transaction_id.append(cust_transaction_id[-1])
            cust_attempt_no.append(cust_attempt_no[-1]+1) # take last entry and add 1


df_t_processed["meta_customer_trx_id"] = cust_transaction_id
df_t_processed["meta_customer_atpt_no"] = cust_attempt_no
df_t_processed = df_t_processed.drop(columns=["time_diff_min"])

# %% [markdown]
# **Auswertung aus der Perspektive der PSPs:**<br>
# Innerhalb eines Kundenvorgangs können mehrere unterschiedliche PSPs gewählt werden. Dabei kommt es auch vor, dass ein PSP, mit dem bei diesem Kundenvorgang bereits ein Versuch unternommen wurde, nach erfolglosen Versuchen mit anderen PSPs wieder ausgewählt wird.<br>
#
# Ziel:<br>
# Kundenvorgänge aus die PSPs aufteilen und eine eindeutige ID des Kundenvorgangs für den jeweiligen PSP schaffen

# %%
df_t_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50410 entries, 0 to 50409
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   x_tmsp                 50410 non-null  datetime64[ns]
#  1   x_country              50410 non-null  object
#  2   x_amount               50410 non-null  int64
#  3   y_success              50410 non-null  int64
#  4   x_psp                  50410 non-null  object
#  5   x_3d_secured           50410 non-null  int64
#  6   x_card                 50410 non-null  object
#  7   meta_customer_trx_id   50410 non-null  int64
#  8   meta_customer_atpt_no  50410 non-null  int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 3.5+ MB

# %%
list_index = []
psp_transaction_id = [] # from PSP perspective: ID for each transaction ; can consist of several attempts
psp_attempt_no = [] # from PSP perspective: no. of attempts for each transaction

for psp in df_t_processed["x_psp"].unique(): # iter over PSPs
    df_filter_psp = df_t_processed[df_t_processed["x_psp"] == psp] # filter by PSP

    list_trx_ids = df_filter_psp["meta_customer_trx_id"].unique() # get all transaction IDs per PSP
    
    for trx_id in list_trx_ids: # iter over transactions
        # records per trax_id
        index_per_trx =  df_filter_psp[df_filter_psp["meta_customer_trx_id"] == trx_id].index

        counter_per_trx = 0 # init counter for attempt no
        # create psp_trx_id
        if len(psp_transaction_id) == 0: # first id
            psp_trx_id = 0
        else:
            psp_trx_id = psp_transaction_id[-1]+1
        
        for index in index_per_trx: # iter over records per trax_id
            list_index.append(index)
            psp_transaction_id.append(psp_trx_id)

            # count attempt per PSP per customer transaction
            counter_per_trx +=1
            psp_attempt_no.append(counter_per_trx)
            

# consolidate data
psp_dict = {"index": list_index, "meta_psp_trx_id": psp_transaction_id, "meta_psp_atpt_no": psp_attempt_no}
df_psp_data = pd.DataFrame(data=psp_dict, columns=["index", "meta_psp_trx_id", "meta_psp_atpt_no"]).set_index("index")
df_t_enrich = df_t_processed.join(df_psp_data, how="left")

# %%
#df_t_enrich.tail(50)

# %% [markdown]
# ### Zeitreiheninformationen und Cyclical Encoding
# Aufsplitten von tmsp in neue Features zur Zeitreihe:
# - Stunde
# - Wochentag
# - Tag (im Monat bzw. Jahr) -> macht nur Sinn, wenn wir mehr Traininsdaten haben
# - Monat -> macht nur Sinn, wenn wir mehr Traininsdaten haben
#
# Für Modelle, die numerische Features verlangen:<br>
# Diese numerischen Features müssen so umgewandelt werden, dass der zyklische Character erhalten bleibt.<br>
# https://www.kaggle.com/code/avanwyk/encoding-cyclical-features-for-deep-learning/notebook

# %%
# create features
df_t_enrich["x_tmsp_h"] = df_t_enrich["x_tmsp"].dt.hour
df_t_enrich["x_tmsp_wd"] = df_t_enrich["x_tmsp"].dt.dayofweek

# weekday no. to string
dict_weekdays = {0: "Monday", 1: "Tuesday", 2: "Wednesday", 3:"Thursday", 4: "Friday", 5: "Saturday", 6: "Sunday"}
df_t_enrich["x_tmsp_wd_str"] = df_t_enrich["x_tmsp_wd"].map(dict_weekdays)

# binning/bucketizing of h into daytime
#df_t_enrich["x_tmsp_daytime"] = df_t_enrich["x_tmsp_h"].apply(binning_h)

# %%
# cyclical encoding
df_t_enrich[["x_tmsp_h_sin", "x_tmsp_h_cos"]] = df_t_enrich.apply(lambda x: cyclical_encoding(x["x_tmsp_h"], 24), axis=1, result_type="expand")
df_t_enrich[["x_tmsp_wd_sin", "x_tmsp_wd_cos"]] = df_t_enrich.apply(lambda x: cyclical_encoding(x["x_tmsp_wd"], 7), axis=1, result_type="expand")

# %%
# drop column for h and wd as int: not required anymore as it is represented as str and sin/cos
df_t_enrich = df_t_enrich.drop(columns=["x_tmsp_h", "x_tmsp_wd"])

# %%
df_t_enrich.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50410 entries, 0 to 50409
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   x_tmsp                 50410 non-null  datetime64[ns]
#  1   x_country              50410 non-null  object
#  2   x_amount               50410 non-null  int64
#  3   y_success              50410 non-null  int64
#  4   x_psp                  50410 non-null  object
#  5   x_3d_secured           50410 non-null  int64
#  6   x_card                 50410 non-null  object
#  7   meta_customer_trx_id   50410 non-null  int64
#  8   meta_customer_atpt_no  50410 non-null  int64
#  9   meta_psp_trx_id        50410 non-null  int64
#  10  meta_psp_atpt_no       50410 non-null  int64
#  11  x_tmsp_wd_str          50410 non-null  object
#  12  x_tmsp_h_sin           50410 non-null  float64
#  13  x_tmsp_h_cos           50410 non-null  float64
#  14  x_tmsp_wd_sin          50410 non-null  float64
#  15  x_tmsp_wd_cos          50410 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int64(7), object(4)
# memory usage: 6.2+ MB

# %% [markdown]
# ### Categorical Encoding
# One hot encoding of:
# - Country
# - PSP
# - Card

# %%
# COUNTRY
ohe_country = pd.get_dummies(df_t_enrich["x_country"], prefix="x_enc_country", prefix_sep="_", drop_first=False)

# PSP
ohe_psp = pd.get_dummies(df_t_enrich["x_psp"], prefix="x_enc_psp", prefix_sep="_", drop_first=False)

# card
ohe_card = pd.get_dummies(df_t_enrich["x_card"], prefix="x_enc_card", prefix_sep="_", drop_first=False)

# %%
df_t_encoded = pd.concat(objs=[df_t_enrich, ohe_country, ohe_psp, ohe_card], axis=1, ignore_index=False)

# %% [markdown]
# # Business understanding 2
# Um die Ziele der Businessfunktion zu erfüllen, ist es wichtig, einige KPI als Erfoglskriterien zu erfassen. Das Prognosemodell muss besser Ergebnisse erzielen.

# %%
#df_t_encoded.describe()

# %% [markdown]
# ## Kosten für die Transaktionen
# Verwendet den gesamten Datensatz

# %%
# melt cost df for easy merge with transactions
df_cost_in = df_cost_in.rename(columns={"fee_success_EUR":1, "fee_failed_EUR":0}) # rename first
df_cost_melted = pd.melt(df_cost_in, id_vars="PSP_name", value_vars=[0, 1], var_name="success_fail", value_name="fee_EUR")

df_t_cost = pd.merge(df_t_encoded, df_cost_melted, 
                     how="left", 
                     left_on=["x_psp", "y_success"], right_on=["PSP_name", "success_fail"])

# %%
total_fee_eur = df_t_cost["fee_EUR"].sum()

trx_all_count = df_t_encoded.shape[0] # count transactions
customer_payments_count = len(df_t_encoded["meta_customer_trx_id"].unique())

avg_cost_per_trx = total_fee_eur / trx_all_count
avg_cost_per_customer_payment = total_fee_eur / customer_payments_count

print(f"Die gesamten Kosten für die {trx_all_count} Transaktionen belaufen sich auf {total_fee_eur:.0f} EUR.\n Damit ergeben sich durchschnittlich {avg_cost_per_trx:.1f} EUR je Transaktion bzw. {avg_cost_per_customer_payment:.1f} EUR je Bezahlvorgang")
# Out:
# Die gesamten Kosten für die 50410 Transaktionen belaufen sich auf 88544 EUR.
#  Damit ergeben sich durchschnittlich 1.8 EUR je Transaktion bzw. 3.3 EUR je Bezahlvorgang

# %% [markdown]
# ## "First time through" von Kundenvorgängen (Bezahlvorgängen)
# Relevant aus Kundenperspektive

# %%
# for ALL payments: attempts per customer
attempts_per_customer = (df_t_encoded.groupby(["meta_customer_trx_id"])["meta_customer_atpt_no"].max()
                         .reset_index()
                         .rename(columns={"meta_customer_atpt_no":"max_customer_atpt"}))

plt.figure(figsize=(plot_width, plot_height+3))
g = sns.displot(attempts_per_customer, x="max_customer_atpt", bins=df_t_encoded["meta_customer_atpt_no"].unique())
plt.xticks(df_t_encoded["meta_customer_atpt_no"].unique())
#g.set_xticklabels(df_t_encoded["meta_customer_atpt_no"].unique())
plt.subplots_adjust(top=0.95)
plt.title("Customer attempts per payment (for ALL payments)")
plt.savefig("../reports/figures/4-4-2_histogram_payment_attempts.png")
plt.show()
plt.close()

# %%
# average no. of attempts for a customer
avg_atpt_per_customer = attempts_per_customer["max_customer_atpt"].mean()
print(f"Ein Kunde muss im Schnitt {avg_atpt_per_customer:.2f} Versuche unternehmen, um die Bezahlung durchzuführen.")
# Out:
# Ein Kunde muss im Schnitt 1.87 Versuche unternehmen, um die Bezahlung durchzuführen.

# %%
# FTT: first time through
attempts_per_customer["FTT"] = attempts_per_customer["max_customer_atpt"].apply(lambda x: True if x==1 else False)

# group by FTT
ftt_calculate = (attempts_per_customer.groupby(["FTT"])[["meta_customer_trx_id"]].count().reset_index()
                 .rename(columns={"meta_customer_trx_id":"payments_count"}))

# %%
plt.figure(figsize=(plot_width-4, plot_height-4))
plt.pie(ftt_calculate["payments_count"], labels=ftt_calculate["FTT"], autopct='%1.1f%%')
plt.title("First time through (FTT) rate of customer payments")
plt.show()
plt.close()

# %% [markdown]
# # Data understanding 2

# %% [markdown]
# ## Collect data
# Für das Prognosemodell ist es sinnvoll, nur die jeweils ersten Versuche eines PSPs für einen Kundenvorgang zu nehmen.
# > Filtern nach "meta_psp_atpt_no" = 1.<br>
# > Damit können je Kundenvorgang mehrere Transaktionen berücksichtigt werden, aber für jeden PSP wird der Kundenvorgang nur 1 Mal aufgenommen und fließt in das Modell ein.

# %%
df_t_encoded.groupby(["meta_psp_atpt_no"])["x_tmsp"].count()
# Out:
# meta_psp_atpt_no
# 1    37782
# 2     8822
# 3     2568
# 4      802
# 5      281
# 6      117
# 7       31
# 8        4
# 9        3
# Name: x_tmsp, dtype: int64

# %%
df_trx = df_t_encoded[df_t_encoded["meta_psp_atpt_no"] == 1]
df_trx.shape
print(f"Wenn je PSP nur der 1. Versuch berücksichtigt wird, verbleiben {df_trx.shape[0]} Datensätze")
# Out:
# Wenn je PSP nur der 1. Versuch berücksichtigt wird, verbleiben 37782 Datensätze

# %%
# raw x- and y-variables
x_ = [x for x in list(df_trx.columns) if re.match("^x_", x)!=None]
y_ = [y for y in list(df_trx.columns) if re.match("^y_", y)!=None]
meta_ = [m for m in list(df_trx.columns) if m.find("meta_")!=-1]

# %% [markdown]
# ## Describe data

# %%
df_trx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37782 entries, 0 to 50404
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   x_tmsp                     37782 non-null  datetime64[ns]
#  1   x_country                  37782 non-null  object
#  2   x_amount                   37782 non-null  int64
#  3   y_success                  37782 non-null  int64
#  4   x_psp                      37782 non-null  object
#  5   x_3d_secured               37782 non-null  int64
#  6   x_card                     37782 non-null  object
#  7   meta_customer_trx_id       37782 non-null  int64
#  8   meta_customer_atpt_no      37782 non-null  int64
#  9   meta_psp_trx_id            37782 non-null  int64
#  10  meta_psp_atpt_no           37782 non-null  int64
#  11  x_tmsp_wd_str              37782 non-null  object
#  12  x_tmsp_h_sin               37782 non-null  float64
#  13  x_tmsp_h_cos               37782 non-null  float64
#  14  x_tmsp_wd_sin              37782 non-null  float64
#  15  x_tmsp_wd_cos              37782 non-null  float64
#  16  x_enc_country_Austria      37782 non-null  bool
#  17  x_enc_country_Germany      37782 non-null  bool
#  18  x_enc_country_Switzerland  37782 non-null  bool
#  19  x_enc_psp_Goldcard         37782 non-null  bool
#  20  x_enc_psp_Moneycard        37782 non-null  bool
#  21  x_enc_psp_Simplecard       37782 non-null  bool
#  22  x_enc_psp_UK_Card          37782 non-null  bool
#  23  x_enc_card_Diners          37782 non-null  bool
#  24  x_enc_card_Master          37782 non-null  bool
#  25  x_enc_card_Visa            37782 non-null  bool
# dtypes: bool(10), datetime64[ns](1), float64(4), int64(7), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# ## Explore data

# %% [markdown]
# ### Erfolgsquote je PSP
# Für den jeweiligen PSP die erste Transaktion je Kundenvorgang

# %%
success_rate = (df_trx.groupby(["x_psp", "y_success"])[["meta_psp_trx_id"]].count()
                .reset_index()
                .rename(columns={"meta_psp_trx_id":"count"})
                .pivot(index="x_psp", columns="y_success", values="count")
                .reset_index())
success_rate["total"] = success_rate[0] + success_rate[1]
success_rate["1_share"] = success_rate[1] / success_rate["total"] * 100
success_rate["total_share"] = success_rate["total"] / success_rate["total"] * 100

# %%
# calculate overall success rate over all PSPs
overall_success_rate = success_rate[1].sum(axis=0) / success_rate["total"].sum(axis=0) * 100
overall_success_rate
# Out:
# 20.628870890900426

# %%
# https://python-graph-gallery.com/stacked-and-percent-stacked-barplot/
plt.figure(figsize=(plot_width-2, plot_height-3))
# bar chart 1 -> top bars (total_share = 100%)
bar1 = sns.barplot(x="x_psp",  y="total_share", data=success_rate, color=color_pal[1])

# bar chart 2 -> bottom bars (group of 'smoker=Yes')
bar2 = sns.barplot(x="x_psp",  y="1_share", data=success_rate, color=color_pal[2])
for i in bar2.containers:
    bar2.bar_label(i, fmt="%.1f")
bar2.set(xlabel="PSP")
bar2.set(ylabel=None)

# add legend
top_bar = mpatches.Patch(color=color_pal[1], label="transaction failed")
bottom_bar = mpatches.Patch(color=color_pal[2], label="transaction successful")
plt.legend(handles=[top_bar, bottom_bar])

plt.title(f"Success rate per PSP (for first transaction per payment) - Overall success rate {overall_success_rate: .1f} %")
plt.savefig("../reports/figures/5-3-1_psp_success.png")
plt.show()
plt.close()

# %% [markdown]
# ### Verteilung über Histogramme

# %%
fig, axs = plt.subplots(1,2, figsize=(10, 4), sharex=False, tight_layout=True)

# Timestamp daytime
# use pd.Categorical for ordering x-axis
"""df_trx["x_tmsp_daytime"] = pd.Categorical(values=df_trx["x_tmsp_daytime"], categories=["morning", "afternoon", "evening", "night"], ordered=True)
sns.histplot(df_trx, x="x_tmsp_daytime", stat="count", ax=axs[0], discrete=True)
axs[0].set_title("Feature: timestamp to daytime")"""

# Timestamp week day
# use pd.Categorical for ordering x-axis
df_trx["x_tmsp_wd_str"] = pd.Categorical(values=df_trx["x_tmsp_wd_str"], categories=list(dict_weekdays.values()), ordered=True)
sns.histplot(df_trx, x="x_tmsp_wd_str", stat="count", ax=axs[1], discrete=True)
axs[1].set_title("Feature: timestamp week day")

plt.subplots_adjust(hspace=0.3, top = 0.93, bottom = 0.02) 
fig.suptitle("Histograms of variables") 
plt.show() 
plt.close()
# Out:
# C:\Users\czump\AppData\Local\Temp\ipykernel_23148\2054687630.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_trx["x_tmsp_wd_str"] = pd.Categorical(values=df_trx["x_tmsp_wd_str"], categories=list(dict_weekdays.values()), ordered=True)

# %% [markdown]
# ### Korrelation überprüfen

# %%
corr_pearson_trx = df_trx[x_ + y_].corr(method="pearson", numeric_only=True)

# %%
sns.heatmap(corr_pearson_trx, annot=True, vmin=-1, vmax=1, center=0.0, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >

# %%
"""corr_grid_trx = sns.PairGrid(df_trx, hue=y_raw[0], palette=palette_success, vars=x_)
corr_grid_trx.map(plt.scatter)
plt.show()"""
# Out:
# 'corr_grid_trx = sns.PairGrid(df_trx, hue=y_raw[0], palette=palette_success, vars=x_)\ncorr_grid_trx.map(plt.scatter)\nplt.show()'

# %%
corr_matrix_trx = df_trx.corr(method="pearson", numeric_only=True)
corr_matrix_trx
# Out:
#                            x_amount  y_success  x_3d_secured  \
# x_amount                   1.000000  -0.068896      0.004592
# y_success                 -0.068896   1.000000      0.076225
# x_3d_secured               0.004592   0.076225      1.000000
# meta_customer_trx_id       0.430927  -0.033438      0.000232
# meta_customer_atpt_no      0.007882  -0.001244     -0.004702
# meta_psp_trx_id            0.143483   0.051938      0.001482
# meta_psp_atpt_no                NaN        NaN           NaN
# x_tmsp_h_sin              -0.011599  -0.022436     -0.004611
# x_tmsp_h_cos              -0.015233  -0.029270      0.002025
# x_tmsp_wd_sin             -0.006488  -0.030773     -0.007133
# x_tmsp_wd_cos             -0.008017  -0.000710     -0.000880
# x_enc_country_Austria     -0.002737   0.001680      0.005247
# x_enc_country_Germany      0.003554  -0.002330     -0.001655
# x_enc_country_Switzerland -0.001617   0.001174     -0.003147
# x_enc_psp_Goldcard         0.003646   0.148098      0.003667
# x_enc_psp_Moneycard       -0.002008   0.014649      0.001113
# x_enc_psp_Simplecard      -0.006152  -0.074175     -0.002413
# x_enc_psp_UK_Card          0.005151  -0.026754     -0.000740
# x_enc_card_Diners          0.004022   0.026828      0.011766
# x_enc_card_Master         -0.005764  -0.020964     -0.000243
# x_enc_card_Visa            0.002985  -0.000588     -0.010752
#
#                            meta_customer_trx_id  meta_customer_atpt_no  \
# x_amount                               0.430927               0.007882
# y_success                             -0.033438              -0.001244
# x_3d_secured                           0.000232              -0.004702
# meta_customer_trx_id                   1.000000               0.008005
# meta_customer_atpt_no                  0.008005               1.000000
# meta_psp_trx_id                        0.324550              -0.100810
# meta_psp_atpt_no                            NaN                    NaN
# x_tmsp_h_sin                           0.005252              -0.002487
# x_tmsp_h_cos                          -0.007678              -0.002840
# x_tmsp_wd_sin                         -0.005210               0.040519
# x_tmsp_wd_cos                          0.004802               0.002982
# x_enc_country_Austria                 -0.690473              -0.015461
# x_enc_country_Germany                 -0.018919               0.019592
# x_enc_country_Switzerland              0.700888              -0.008554
# x_enc_psp_Goldcard                     0.009210               0.065439
# x_enc_psp_Moneycard                   -0.005386               0.097263
# x_enc_psp_Simplecard                   0.000687               0.069713
# x_enc_psp_UK_Card                     -0.001422              -0.177210
# x_enc_card_Diners                      0.005994               0.007433
# x_enc_card_Master                     -0.010942               0.002877
# x_enc_card_Visa                        0.007206              -0.010345
#
#                            meta_psp_trx_id  meta_psp_atpt_no  x_tmsp_h_sin  \
# x_amount                          0.143483               NaN     -0.011599
# y_success                         0.051938               NaN     -0.022436
# x_3d_secured                      0.001482               NaN     -0.004611
# meta_customer_trx_id              0.324550               NaN      0.005252
# meta_customer_atpt_no            -0.100810               NaN     -0.002487
# meta_psp_trx_id                   1.000000               NaN     -0.000292
# meta_psp_atpt_no                       NaN               NaN           NaN
# x_tmsp_h_sin                     -0.000292               NaN      1.000000
# x_tmsp_h_cos                     -0.005567               NaN      0.001064
# x_tmsp_wd_sin                     0.004120               NaN     -0.001924
# x_tmsp_wd_cos                     0.006436               NaN      0.000246
# x_enc_country_Austria            -0.226316               NaN     -0.011116
# x_enc_country_Germany            -0.001783               NaN      0.003788
# x_enc_country_Switzerland         0.224378               NaN      0.006326
# x_enc_psp_Goldcard                0.477016               NaN      0.001658
# x_enc_psp_Moneycard              -0.687981               NaN      0.005062
# x_enc_psp_Simplecard             -0.353501               NaN     -0.004268
# x_enc_psp_UK_Card                 0.605730               NaN     -0.001108
# x_enc_card_Diners                 0.001537               NaN      0.008290
# x_enc_card_Master                -0.012127               NaN     -0.009853
# x_enc_card_Visa                   0.012775               NaN      0.003775
#
#                            x_tmsp_h_cos  x_tmsp_wd_sin  x_tmsp_wd_cos  \
# x_amount                      -0.015233      -0.006488      -0.008017
# y_success                     -0.029270      -0.030773      -0.000710
# x_3d_secured                   0.002025      -0.007133      -0.000880
# meta_customer_trx_id          -0.007678      -0.005210       0.004802
# meta_customer_atpt_no         -0.002840       0.040519       0.002982
# meta_psp_trx_id               -0.005567       0.004120       0.006436
# meta_psp_atpt_no                    NaN            NaN            NaN
# x_tmsp_h_sin                   0.001064      -0.001924       0.000246
# x_tmsp_h_cos                   1.000000      -0.002039      -0.003850
# x_tmsp_wd_sin                 -0.002039       1.000000       0.024285
# x_tmsp_wd_cos                 -0.003850       0.024285       1.000000
# x_enc_country_Austria          0.008741       0.004829      -0.010023
# x_enc_country_Germany         -0.011569      -0.002089       0.004648
# x_enc_country_Switzerland      0.005432      -0.002210       0.004210
# x_enc_psp_Goldcard            -0.005399       0.003803       0.004674
# x_enc_psp_Moneycard            0.000912      -0.005758       0.000892
# x_enc_psp_Simplecard           0.002928       0.000884      -0.009083
# x_enc_psp_UK_Card             -0.000384       0.001697       0.004913
# x_enc_card_Diners             -0.021283      -0.013920      -0.008880
# x_enc_card_Master              0.014753       0.008514       0.003266
# x_enc_card_Visa                0.002668       0.003075       0.004500
#
#                            x_enc_country_Austria  x_enc_country_Germany  \
# x_amount                               -0.002737               0.003554
# y_success                               0.001680              -0.002330
# x_3d_secured                            0.005247              -0.001655
# meta_customer_trx_id                   -0.690473              -0.018919
# meta_customer_atpt_no                  -0.015461               0.019592
# meta_psp_trx_id                        -0.226316              -0.001783
# meta_psp_atpt_no                             NaN                    NaN
# x_tmsp_h_sin                           -0.011116               0.003788
# x_tmsp_h_cos                            0.008741              -0.011569
# x_tmsp_wd_sin                           0.004829              -0.002089
# x_tmsp_wd_cos                          -0.010023               0.004648
# x_enc_country_Austria                   1.000000              -0.601808
# x_enc_country_Germany                  -0.601808               1.000000
# x_enc_country_Switzerland              -0.252835              -0.620535
# x_enc_psp_Goldcard                     -0.011159               0.004347
# x_enc_psp_Moneycard                     0.005270              -0.001586
# x_enc_psp_Simplecard                   -0.001059              -0.002530
# x_enc_psp_UK_Card                       0.002932               0.001147
# x_enc_card_Diners                       0.003871              -0.014260
# x_enc_card_Master                       0.006307               0.003003
# x_enc_card_Visa                        -0.011025               0.009855
#
#                            x_enc_country_Switzerland  x_enc_psp_Goldcard  \
# x_amount                                   -0.001617            0.003646
# y_success                                   0.001174            0.148098
# x_3d_secured                               -0.003147            0.003667
# meta_customer_trx_id                        0.700888            0.009210
# meta_customer_atpt_no                      -0.008554            0.065439
# meta_psp_trx_id                             0.224378            0.477016
# meta_psp_atpt_no                                 NaN                 NaN
# x_tmsp_h_sin                                0.006326            0.001658
# x_tmsp_h_cos                                0.005432           -0.005399
# x_tmsp_wd_sin                              -0.002210            0.003803
# x_tmsp_wd_cos                               0.004210            0.004674
# x_enc_country_Austria                      -0.252835           -0.011159
# x_enc_country_Germany                      -0.620535            0.004347
# x_enc_country_Switzerland                   1.000000            0.005691
# x_enc_psp_Goldcard                          0.005691            1.000000
# x_enc_psp_Moneycard                        -0.003253           -0.148382
# x_enc_psp_Simplecard                        0.004104           -0.187472
# x_enc_psp_UK_Card                          -0.004268           -0.266381
# x_enc_card_Diners                           0.013474            0.009537
# x_enc_card_Master                          -0.009831           -0.012879
# x_enc_card_Visa                            -0.001113            0.006153
#
#                            x_enc_psp_Moneycard  x_enc_psp_Simplecard  \
# x_amount                             -0.002008             -0.006152
# y_success                             0.014649             -0.074175
# x_3d_secured                          0.001113             -0.002413
# meta_customer_trx_id                 -0.005386              0.000687
# meta_customer_atpt_no                 0.097263              0.069713
# meta_psp_trx_id                      -0.687981             -0.353501
# meta_psp_atpt_no                           NaN                   NaN
# x_tmsp_h_sin                          0.005062             -0.004268
# x_tmsp_h_cos                          0.000912              0.002928
# x_tmsp_wd_sin                        -0.005758              0.000884
# x_tmsp_wd_cos                         0.000892             -0.009083
# x_enc_country_Austria                 0.005270             -0.001059
# x_enc_country_Germany                -0.001586             -0.002530
# x_enc_country_Switzerland            -0.003253              0.004104
# x_enc_psp_Goldcard                   -0.148382             -0.187472
# x_enc_psp_Moneycard                   1.000000             -0.308611
# x_enc_psp_Simplecard                 -0.308611              1.000000
# x_enc_psp_UK_Card                    -0.438508             -0.554031
# x_enc_card_Diners                     0.006144             -0.004398
# x_enc_card_Master                     0.001356              0.007684
# x_enc_card_Visa                      -0.007353             -0.004883
#
#                            x_enc_psp_UK_Card  x_enc_card_Diners  \
# x_amount                            0.005151           0.004022
# y_success                          -0.026754           0.026828
# x_3d_secured                       -0.000740           0.011766
# meta_customer_trx_id               -0.001422           0.005994
# meta_customer_atpt_no              -0.177210           0.007433
# meta_psp_trx_id                     0.605730           0.001537
# meta_psp_atpt_no                         NaN                NaN
# x_tmsp_h_sin                       -0.001108           0.008290
# x_tmsp_h_cos                       -0.000384          -0.021283
# x_tmsp_wd_sin                       0.001697          -0.013920
# x_tmsp_wd_cos                       0.004913          -0.008880
# x_enc_country_Austria               0.002932           0.003871
# x_enc_country_Germany               0.001147          -0.014260
# x_enc_country_Switzerland          -0.004268           0.013474
# x_enc_psp_Goldcard                 -0.266381           0.009537
# x_enc_psp_Moneycard                -0.438508           0.006144
# x_enc_psp_Simplecard               -0.554031          -0.004398
# x_enc_psp_UK_Card                   1.000000          -0.006226
# x_enc_card_Diners                  -0.006226           1.000000
# x_enc_card_Master                  -0.000894          -0.570293
# x_enc_card_Visa                     0.006889          -0.269408
#
#                            x_enc_card_Master  x_enc_card_Visa
# x_amount                           -0.005764         0.002985
# y_success                          -0.020964        -0.000588
# x_3d_secured                       -0.000243        -0.010752
# meta_customer_trx_id               -0.010942         0.007206
# meta_customer_atpt_no               0.002877        -0.010345
# meta_psp_trx_id                    -0.012127         0.012775
# meta_psp_atpt_no                         NaN              NaN
# x_tmsp_h_sin                       -0.009853         0.003775
# x_tmsp_h_cos                        0.014753         0.002668
# x_tmsp_wd_sin                       0.008514         0.003075
# x_tmsp_wd_cos                       0.003266         0.004500
# x_enc_country_Austria               0.006307        -0.011025
# x_enc_country_Germany               0.003003         0.009855
# x_enc_country_Switzerland          -0.009831        -0.001113
# x_enc_psp_Goldcard                 -0.012879         0.006153
# x_enc_psp_Moneycard                 0.001356        -0.007353
# x_enc_psp_Simplecard                0.007684        -0.004883
# x_enc_psp_UK_Card                  -0.000894         0.006889
# x_enc_card_Diners                  -0.570293        -0.269408
# x_enc_card_Master                   1.000000        -0.637429
# x_enc_card_Visa                    -0.637429         1.000000

# %% [markdown]
# # Save data

# %% [markdown]
# ## Save training data
# Nur die jeweils ersten Versuche eines PSPs für einen Kundenvorgang

# %%
df_trx.to_excel("../data/04_processed/df_trx_training.xlsx", sheet_name="df_trx")

# %%
#df_trx.info()

# %% [markdown]
# ## Save all transactions
# Evtl. für die spätere Simulation

# %%
df_t_encoded.to_excel("../data/04_processed/df_trx_all.xlsx", sheet_name="df_t_all")

# %% [markdown]
# ## Save cost data

# %%
df_cost_in.to_excel("../data/04_processed/df_cost_in.xlsx", sheet_name="df_cost_in")
